# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %%
df.shape
# Out:
# (28, 3)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df[['age', 'affordibility']],df.bought_insurance, test_size = 0.3, random_state = 25)

# %%
len(x_train)
# Out:
# 19

# %%
x_train_scaled = x_train.copy()
x_train_scaled['age'] = x_train_scaled['age']/100

x_test_scaled = x_test.copy()
x_test_scaled['age'] = x_test_scaled['age']/100

# %%
model = keras.Sequential([
    keras.layers.Dense(1, input_shape = (2,), activation = 'sigmoid', kernel_initializer = 'ones', bias_initializer = 'zeros')
])

model.compile(optimizer = 'adam',
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])
model.fit(x_train_scaled, y_train, epochs = 50)
# Out:
# D:\DeepLearning\venv\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 899ms/step - accuracy: 0.5789 - loss: 0.6482
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5789 - loss: 0.6480
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5789 - loss: 0.6477
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5789 - loss: 0.6475
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5789 - loss: 0.6472
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6470
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5789 - loss: 0.6467
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5789 - loss: 0.6464
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6462
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5789 - loss: 0.6459
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6457
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6454
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5789 - loss: 0.6452
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5789 - loss: 0.6449
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5789 - loss: 0.6447
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6444
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5789 - loss: 0.6442
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5789 - loss: 0.6440
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5789 - loss: 0.6437
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6435
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6432
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6430
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5789 - loss: 0.6427
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5789 - loss: 0.6425
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5789 - loss: 0.6423
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5789 - loss: 0.6420
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5789 - loss: 0.6418
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5789 - loss: 0.6416
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6413
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5789 - loss: 0.6411
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5789 - loss: 0.6409
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6406
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6404
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6402
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6399
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6397
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6395
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5789 - loss: 0.6393
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5789 - loss: 0.6390
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.5789 - loss: 0.6388
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5789 - loss: 0.6386
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5789 - loss: 0.6384
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5789 - loss: 0.6382
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5789 - loss: 0.6379
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5789 - loss: 0.6377
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5789 - loss: 0.6375
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6373
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6371
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6369
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5789 - loss: 0.6367

# %%
model.evaluate(x_test_scaled, y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.3333 - loss: 0.8259
# [0.8258721232414246, 0.3333333432674408]

# %%
model.predict(x_test_scaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# array([[0.79403913],
#        [0.7452123 ],
#        [0.54942775],
#        [0.76287067],
#        [0.7971369 ],
#        [0.8149933 ],
#        [0.75237817],
#        [0.5564908 ],
#        [0.616464  ]], dtype=float32)

# %%
y_test
# Out:
# 2     1
# 10    0
# 21    0
# 11    0
# 14    1
# 9     1
# 0     0
# 13    0
# 6     0
# Name: bought_insurance, dtype: int64

# %%
coef, intercept = model.get_weights()
coef, intercept
# Out:
# (array([[0.95243984],
#         [0.9510752 ]], dtype=float32),
#  array([-0.04927548], dtype=float32))

# %%
def sigmoid(x):
    import math
    return 1/(1 + math.exp(-x))
sigmoid(18)
# Out:
# 0.9999999847700205

# %%
def prediction_function(age, affordibility):
    weighted_sum = coef[0]*age + coef[1]*affordibility + intercept
    return sigmoid(weighted_sum)

# %%
prediction_function(.47,1)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9764\3885159617.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return 1/(1 + math.exp(-x))
# 0.7940391092372784

# %%
def log_loss(y_true, y_predicted):
    epsilon = 1e-15
    y_predicted_new = [max(i,epsilon) for i in y_predicted]
    y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %%
def sigmoid_numpy(x):
    return 1/(1+np.exp(-x))
sigmoid_numpy(np.array([12,0,1]))
# Out:
# array([0.99999386, 0.5       , 0.73105858])

# %%
class myNN:
    def __init__(self):
        self.w1 = 1
        self.w2 = 1
        self.bias = 0
        
    def fit(self, x, y, epochs, loss_thresold):
        self.w1, self.w2, self.bias = self.gradient_descent(x['age'], x['affordibility'], y, epochs, loss_thresold)

    def predict(self, x_test):
        weigthed_sum = self.w1*x_test['age']+self.w2*x_test['affordibility']+self.bias
        return sigmoid_numpy(weigthed_sum)

    def gradient_descent(self, age, affordibility, y_true, epochs, loss_thresold):
        w1 = w2 = 1
        bias = 0
        rate = 0.5
        n = len(age)
    
        for i in range(epochs):
            weighted_sum = w1 * age + w2* affordibility + bias
            y_predicted = sigmoid_numpy(weighted_sum)
    
            loss = log_loss(y_true, y_predicted)
    
    
            
            w1d = (1/n)*np.dot(np.transpose(age),(y_predicted-y_true))
            w2d = (1/n)*np.dot(np.transpose(affordibility),(y_predicted-y_true))
    
            bias_d = np.mean(y_predicted-y_true)
    
            w1 = w1 - rate * w1d
            w2 = w2 - rate * w2d
            bias = bias - rate * bias_d
            if i%50==0:
                print(f'Epoch:{i}, w1:{w1}, w2:{w2}, bias:{bias}, loss:{loss}')
            if loss<=loss_thresold:
                print(f'Epoch:{i}, w1:{w1}, w2:{w2}, bias:{bias}, loss:{loss}')
                break
    
        return w1, w2, bias

# %%
customModel = myNN()
customModel.fit(x_train_scaled, y_train, epochs = 5000, loss_thresold = 0.4433)
# Out:
# Epoch:0, w1:0.9889590343991516, w2:0.9605100280733173, bias:-0.07926911922718616, loss:0.6482464826346737
# Epoch:50, w1:1.648569513567938, w2:0.995345764889503, bias:-0.9451354427468239, loss:0.5611917372000745
# Epoch:100, w1:2.39104451607289, w2:1.0889211871188738, bias:-1.326573270702499, loss:0.5327623106330734
# Epoch:150, w1:3.0719504952582417, w2:1.1125810233743052, bias:-1.6271016685173572, loss:0.5104777389323873
# Epoch:200, w1:3.691436873278665, w2:1.1106346646465557, bias:-1.8812339449000528, loss:0.4924709416109721
# Epoch:250, w1:4.253684331792159, w2:1.1004893322201528, bias:-2.104513224124534, loss:0.4777715927867156
# Epoch:300, w1:4.764139762509416, w2:1.0888200362932303, bias:-2.3046660209926766, loss:0.46569664904084496
# Epoch:350, w1:5.228329247573219, w2:1.0780002508029816, bias:-2.486044630125024, loss:0.45572170167967513
# Epoch:400, w1:5.651385846479405, w2:1.068705580003656, bias:-2.6514549985153524, loss:0.44743630530495193
# Epoch:429, w1:5.879743295855901, w2:1.0640391485945828, bias:-2.7408977952706097, loss:0.4432746597360118

# %%
customModel.predict(x_test_scaled)
# Out:
# 2     0.734542
# 10    0.675533
# 21    0.486987
# 11    0.696654
# 14    0.738350
# 9     0.760445
# 0     0.684074
# 13    0.494341
# 6     0.557841
# dtype: float64

# %%
model.predict(x_test_scaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# array([[0.79403913],
#        [0.7452123 ],
#        [0.54942775],
#        [0.76287067],
#        [0.7971369 ],
#        [0.8149933 ],
#        [0.75237817],
#        [0.5564908 ],
#        [0.616464  ]], dtype=float32)
